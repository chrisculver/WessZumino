# %%
e0raw0p4=[(-0.17632036-6.6743855e-10j),
 (-0.007432304+2.0544904e-09j),
 (-0.037540335-2.8288923e-08j),
 (-0.16539337-2.0372681e-08j),
 (0.00686349-2.1464075e-10j),
 (0.14828974+2.5518239e-07j),
 (0.12079301+3.1147472e-08j),
 (0.15858257-5.122274e-08j),
 (0.15672453-2.8312206e-07j)]

# %%
e0raw0p2=[(-0.19774175+1.4238921e-08j),
 (-0.52805847-1.4934898e-10j),
 (0.30217743-5.943665e-08j),
 (0.011298315+4.4830813e-08j),
 (0.25084758-4.284084e-08j),
 (0.27226457+1.4762422e-08j),
 (0.27038714-1.07119064e-07j),
 (0.30159748-2.4330802e-07j),
 (0.2938117+7.4505806e-08j)]

# %%
e0raw0p1=[(-0.29921407+5.748845e-09j),
 (-0.5290055+4.3602533e-08j),
 (0.35867193-4.2199765e-08j),
 (0.1285829+2.514571e-08j),
 (0.37933087-9.685755e-08j),
 (0.36232227+1.4901161e-07j),
 (0.37169835+8.614734e-08j),
 (0.39731428-4.5495108e-07j),
 (0.38913086-1.4109537e-07j)]

# %%
e0raw0p3=[(-0.20203061+1.0714117e-08j),
 (-0.27862185+3.1044145e-10j),
 (0.2367526+3.7873647e-08j),
 (-0.086053774+5.401671e-08j),
 (0.12671681-4.1909516e-08j),
 (0.20166524+5.820766e-08j),
 (0.18727054+8.195639e-08j),
 (0.22280538-1.827861e-07j),
 (0.2169671-6.798655e-08j)]

# %%
import matplotlib.pyplot as plt

import matplotlib 
#matplotlib.use("Agg")
plt.style.use("paper.mplstyle")

fig, ax = plt.subplots()

plt.scatter([x for x in range(2,11)],[abs(en.real) for en in e0raw0p1], c='black', marker='o', label='c=-0.1')
plt.scatter([x for x in range(2,11)],[abs(en.real) for en in e0raw0p2], c='red', marker='^', label='c=-0.2')
plt.scatter([x for x in range(2,11)],[abs(en.real) for en in e0raw0p3], c='green', marker='p', label='c=-0.3')
plt.scatter([x for x in range(2,11)],[abs(en.real) for en in e0raw0p4], c='blue', marker='s', label='c=-0.4')

plt.xlabel('$\\Lambda$')
plt.ylabel('$|E|$')

plt.xlim(1.5,10.5)
plt.ylim(0,0.6)
#plt.yscale('log')

ax.text(0.25, 0.92, 'PRELIMINARY', transform=ax.transAxes,
        fontsize=40, color='red', alpha=0.5,
        ha='center', va='center', rotation='0')

plt.legend(loc='upper right')

plt.savefig('PLOTS/WZ_3site_vq2_allc.pdf',bbox_inches='tight')
