# %% [markdown]
# # Wess Zumino
#
# ## N=1 in 1+1
#
# The Hamiltonian with a central difference for the derivative is given by
#
# \begin{align}
#     H=\sum_n&\left[ \frac{p_n^2}{2a} + \frac{a}{2}\left(\frac{\phi_{n+1}-\phi_{n-1}}{2a}\right)^2+\frac{a}{2}V(\phi_n)^2
#             +aV(\phi_n)\frac{\phi_{n+1}-\phi_{n-1}}{2a} \right. \nonumber \\
#             &\left.+(-1)^nV'(\phi_n)\left(\chi_n^{\dagger}\chi_n-\frac{1}{2}\right)
#             +\frac{1}{2a}\left(\chi_n^{\dagger}\chi_{n+1}+\chi_{n+1}^{\dagger}\chi_n\right) \right],
# \end{align}

# %% [markdown]
# ## TODO
#
# - CHECK CORRECTNESS!
# - Use buffer for creating bosonic matrices
#
# Then I can immediately start repeating exercises of 0+1
#
#
# ## Improvements
#
# - Only make matrix of Bosons tensored with fermions (better PS representation)
# - State ordering option for b0-f0-b1-f1-b2-f2 OR b0-b1-b2-f0-f1-f2
#
# ## "Parameters"
#
# - Potential
# - (NEW) Lattice Spacing & Sites
# - (NEW) Boundary conditions
# - Bosonic dof cutoff
# - (NEW) State order - for efficiencies sake.
# - Binary Encoding
#
#
# ## Plan
#
# - Exact diagonalization of Hamiltonian - spectrum vs "parameters"
# - VQE in QISKIT - quantum procedure
# - Machine Learning ground state - compare to old studies
# - Gate count for trotter steps

# %%
import sympy as sp
from ham_to_matrix import *
from constants import *

# %%
bosonNI=sp.expand( pn**2/(2*aLat) + (aLat/2)*((qnP1-qnM1)/(2*aLat))**2 )
bosonI=sp.expand( (aLat/2)*V(qn)**2 + aLat*V(qn)*(qnP1-qnM1)/(2*aLat) )
fermionNI=sp.expand( (xdnP1*xn+xdn*xnP1)/(2*aLat) )
fermionI=sp.expand( (-1)**n*sp.diff(V(qn),qn)*(xdn*xn-(1/2)) )

# %%
bosonNI+bosonI
# Out:
# a*V(q_{n})**2/2 + V(q_{n})*q_{n+1}/2 - V(q_{n})*q_{n-1}/2 + p_{n}**2/(2*a) - q_{n+1}*q_{n-1}/(8*a) + q_{n+1}**2/(8*a) - q_{n-1}*q_{n+1}/(8*a) + q_{n-1}**2/(8*a)

# %%
fermionNI + fermionI
# Out:
# -0.5*(-1)**n*Derivative(V(q_{n}), q_{n}) + (-1)**n*Derivative(V(q_{n}), q_{n})*\chi^{\dagger}_{n}*\chi_{n} + \chi^{\dagger}_{n+1}*\chi_{n}/(2*a) + \chi^{\dagger}_{n}*\chi_{n+1}/(2*a)

# %%
N=3
aVal=1

# depends on finite-difference method
qs=[SiteSymbol('q',str(i)) for i in range(-1,N+1,1)]
# maybe make qs a normal site list
# and make an extra boundaryQs list for q[-1], q[N]
# counting would be normal computer science way for rest of code.

ps=[SiteSymbol('p',str(i)) for i in range(-1,N+1,1)] # don't really need extras
aops=[SiteSymbol('a',str(i)) for i in range(-1,N+1,1)]
adags=[SiteSymbol('a^{\dagger}',str(i)) for i in range(-1,N+1,1)]
xs=[SiteSymbol('\chi',str(i)) for i in range(-1,N+1,1)]
xdags=[SiteSymbol('\chi^{\dagger}',str(i)) for i in range(-1,N+1,1)]

# note this is exactly hardcoded for this finite difference method.
bcType = 'periodic'
boundaryConditions = {}
if bcType == 'periodic':
    boundaryConditions = {qs[0]: qs[N], qs[N+1]: qs[1],
                          xs[0]: -xs[N], xs[N+1]: -xs[1], 
                          xdags[0]: -xdags[N],  xdags[N+1]: -xdags[1]
                         }
    
elif bcType == 'dirichlet':
    boundaryConditions = { qs[0]: 0, qs[N+1]: 0,
                          xs[0]: 0, xs[N+1]: 0,
                          xdags[0]: 0, xdags[N+1]:0
                         }

# %%
totHam=bosonNI+bosonI+fermionNI+fermionI
totHam
# Out:
# -0.5*(-1)**n*Derivative(V(q_{n}), q_{n}) + (-1)**n*Derivative(V(q_{n}), q_{n})*\chi^{\dagger}_{n}*\chi_{n} + a*V(q_{n})**2/2 + V(q_{n})*q_{n+1}/2 - V(q_{n})*q_{n-1}/2 + \chi^{\dagger}_{n+1}*\chi_{n}/(2*a) + \chi^{\dagger}_{n}*\chi_{n+1}/(2*a) + p_{n}**2/(2*a) - q_{n+1}*q_{n-1}/(8*a) + q_{n+1}**2/(8*a) - q_{n-1}*q_{n+1}/(8*a) + q_{n-1}**2/(8*a)

# %%
ham=0

for i in range(1,N+1):
    ham+=(bosonNI+bosonI+fermionNI).subs({
        pn: ps[i],
        qn: qs[i], qnP1: qs[i+1], qnM1: qs[i-1],
        xn: xs[i], xnP1: xs[i+1],
        xdn: xdags[i], xdnP1: xdags[i+1]
    }).subs(boundaryConditions)
    
# ham.subs(boundaryConditions).doit() # this doesn't work?

def potential(n):
    return qs[n]*qs[n]*qs[n]

potentialSubs={}
for n in range(1,N+1):
    potentialSubs[V(qs[n])]=potential(n)

ham=sp.simplify(ham.subs(potentialSubs).subs(aLat,aVal))


for i in range(1,N+1):
    if i%2==0:
        ham+=sp.simplify(fermionI.subs({qn: qs[i], xn: xs[i], xdn: xdags[i]}).subs(potentialSubs)).subs((-1)**n,1)
    else:
        ham-=sp.simplify(fermionI.subs({qn: qs[i], xn: xs[i], xdn: xdags[i]}).subs(potentialSubs)).subs((-1)**n,1)
ham=sp.simplify(ham)
ham
# Out:
# (4*\chi^{\dagger}_{0}*\chi_{1} - 4*\chi^{\dagger}_{0}*\chi_{2} + 4*\chi^{\dagger}_{1}*\chi_{0} + 4*\chi^{\dagger}_{1}*\chi_{2} - 4*\chi^{\dagger}_{2}*\chi_{0} + 4*\chi^{\dagger}_{2}*\chi_{1} + 4*p_{0}**2 + 4*p_{1}**2 + 4*p_{2}**2 - q_{0}*q_{1} - q_{0}*q_{2} + 14.0*q_{0}**2 - 24*q_{0}**2*\chi^{\dagger}_{0}*\chi_{0} + 4*q_{0}**3*q_{1} - 4*q_{0}**3*q_{2} + 4*q_{0}**6 - q_{1}*q_{0} - q_{1}*q_{2} - 10.0*q_{1}**2 + 24*q_{1}**2*\chi^{\dagger}_{1}*\chi_{1} - 4*q_{1}**3*q_{0} + 4*q_{1}**3*q_{2} + 4*q_{1}**6 - q_{2}*q_{0} - q_{2}*q_{1} + 14.0*q_{2}**2 - 24*q_{2}**2*\chi^{\dagger}_{2}*\chi_{2} + 4*q_{2}**3*q_{0} - 4*q_{2}**3*q_{1} + 4*q_{2}**6)/8

# %%
#ham=0
#totHam=bosonNI+bosonI+fermionNI+fermionI
#for i in range(0,N):
#    ham+=totHam.subs(n,i).subs(boundaryConditions)
# ham.subs(boundaryConditions).doit() # this doesn't work?

#def potential(n):
#    return q[n]

#for n in range(0,N):
#    ham=ham.subs(V(q[n]),potential(n))
#ham=ham.subs(aLat,aVal).simplify().expand()
#ham

# %%
m=1

HOdofSubs = {}
#offset because of BC
for i in range(1,N+1):
    HOdofSubs[qs[i]] = 0.5*sp.sqrt(2/m)*(aops[i] + adags[i])
    HOdofSubs[ps[i]] = complex(0,1)*sp.sqrt(2*m)*(adags[i] - aops[i])/2 

hoHam=sp.expand(ham.subs(HOdofSubs))
hoHam=sp.nsimplify(hoHam,tolerance=1e-8)
hoHam
# Out:
# \chi^{\dagger}_{0}*\chi_{1}/2 - \chi^{\dagger}_{0}*\chi_{2}/2 + \chi^{\dagger}_{1}*\chi_{0}/2 + \chi^{\dagger}_{1}*\chi_{2}/2 - \chi^{\dagger}_{2}*\chi_{0}/2 + \chi^{\dagger}_{2}*\chi_{1}/2 - a^{\dagger}_{0}*a^{\dagger}_{1}/16 - a^{\dagger}_{0}*a^{\dagger}_{2}/16 + 9*a^{\dagger}_{0}*a_{0}/8 - 3*a^{\dagger}_{0}*a_{0}*\chi^{\dagger}_{0}*\chi_{0}/2 + a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a^{\dagger}_{1}/8 - a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a^{\dagger}_{2}/8 + a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{0}/16 + a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}**2/16 + a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{0}/16 + a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{0}**3/16 + a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{1}/8 - a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{2}/8 + a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{0}/16 + a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}**2*a_{0}**2/16 + a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}**3*a_{0}/16 + a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}**4/16 + a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}/16 + a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{0}*a_{0}**2/16 + a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{0}**2*a_{0}/16 + a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{0}**3/16 + a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{1}/8 - a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{2}/8 + a^{\dagger}_{0}*a_{0}**2*a_{1}/8 - a^{\dagger}_{0}*a_{0}**2*a_{2}/8 + a^{\dagger}_{0}*a_{0}**3*a^{\dagger}_{0}*a_{0}/16 + a^{\dagger}_{0}*a_{0}**3*a^{\dagger}_{0}**2/16 + a^{\dagger}_{0}*a_{0}**4*a^{\dagger}_{0}/16 + a^{\dagger}_{0}*a_{0}**5/16 - a^{\dagger}_{0}*a_{1}/16 - a^{\dagger}_{0}*a_{2}/16 + 5*a^{\dagger}_{0}**2/8 - 3*a^{\dagger}_{0}**2*\chi^{\dagger}_{0}*\chi_{0}/2 + a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}/16 + a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{0}*a_{0}**2/16 + a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{0}**2*a_{0}/16 + a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{0}**3/16 + a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{1}/8 - a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{2}/8 + a^{\dagger}_{0}**2*a_{0}*a_{1}/8 - a^{\dagger}_{0}**2*a_{0}*a_{2}/8 + a^{\dagger}_{0}**2*a_{0}**2*a^{\dagger}_{0}*a_{0}/16 + a^{\dagger}_{0}**2*a_{0}**2*a^{\dagger}_{0}**2/16 + a^{\dagger}_{0}**2*a_{0}**3*a^{\dagger}_{0}/16 + a^{\dagger}_{0}**2*a_{0}**4/16 + a^{\dagger}_{0}**3*a^{\dagger}_{1}/8 - a^{\dagger}_{0}**3*a^{\dagger}_{2}/8 + a^{\dagger}_{0}**3*a_{0}*a^{\dagger}_{0}*a_{0}/16 + a^{\dagger}_{0}**3*a_{0}*a^{\dagger}_{0}**2/16 + a^{\dagger}_{0}**3*a_{0}**2*a^{\dagger}_{0}/16 + a^{\dagger}_{0}**3*a_{0}**3/16 + a^{\dagger}_{0}**3*a_{1}/8 - a^{\dagger}_{0}**3*a_{2}/8 + a^{\dagger}_{0}**4*a_{0}*a^{\dagger}_{0}/16 + a^{\dagger}_{0}**4*a_{0}**2/16 + a^{\dagger}_{0}**5*a_{0}/16 + a^{\dagger}_{0}**6/16 - a^{\dagger}_{1}*a^{\dagger}_{0}/16 - a^{\dagger}_{1}*a^{\dagger}_{2}/16 - a^{\dagger}_{1}*a_{0}/16 - 3*a^{\dagger}_{1}*a_{1}/8 + 3*a^{\dagger}_{1}*a_{1}*\chi^{\dagger}_{1}*\chi_{1}/2 - a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a^{\dagger}_{0}/8 + a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a^{\dagger}_{2}/8 - a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{0}/8 + a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{1}/16 + a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}**2/16 + a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{1}/16 + a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{1}**3/16 + a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{2}/8 + a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}**2*a_{1}*a^{\dagger}_{1}/16 + a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}**2*a_{1}**2/16 + a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}**3*a_{1}/16 + a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}**4/16 - a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{0}/8 + a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}/16 + a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{1}*a_{1}**2/16 + a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{1}**2*a_{1}/16 + a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{1}**3/16 + a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{2}/8 - a^{\dagger}_{1}*a_{1}**2*a_{0}/8 + a^{\d ...

# %%
len(hoHam.args)
# Out:
# 342

# %%
342*5/60
# Out:
# 28.5

# %%
cutoff=4
hamMat=convert_to_matrix(hoHam,cutoff,N,aops,adags,xs,xdags)
# Out:
# -7*a^{\dagger}_{1}**2/8 to matrix timer took: 37.3690 seconds
# -7*a_{1}**2/8 to matrix timer took: 23.4654 seconds
# a^{\dagger}_{0}**6/16 to matrix timer took: 23.5476 seconds
# a^{\dagger}_{1}**6/16 to matrix timer took: 23.5326 seconds
# a^{\dagger}_{2}**6/16 to matrix timer took: 23.2415 seconds
# a_{0}**6/16 to matrix timer took: 23.5762 seconds
# a_{1}**6/16 to matrix timer took: 23.5671 seconds
# a_{2}**6/16 to matrix timer took: 23.3050 seconds
# 5*a^{\dagger}_{0}**2/8 to matrix timer took: 23.4164 seconds
# 5*a^{\dagger}_{2}**2/8 to matrix timer took: 23.4119 seconds
# 5*a_{0}**2/8 to matrix timer took: 23.4773 seconds
# 5*a_{2}**2/8 to matrix timer took: 23.6868 seconds
# \chi^{\dagger}_{0}*\chi_{1}/2 to matrix timer took: 33.9833 seconds
# \chi^{\dagger}_{1}*\chi_{0}/2 to matrix timer took: 33.4118 seconds
# \chi^{\dagger}_{1}*\chi_{2}/2 to matrix timer took: 32.7305 seconds
# \chi^{\dagger}_{2}*\chi_{1}/2 to matrix timer took: 32.4645 seconds
# -3*a^{\dagger}_{1}*a_{1}/8 to matrix timer took: 33.2858 seconds
# -3*a_{1}*a^{\dagger}_{1}/8 to matrix timer took: 33.2192 seconds
# -\chi^{\dagger}_{0}*\chi_{2}/2 to matrix timer took: 32.7731 seconds
# -\chi^{\dagger}_{2}*\chi_{0}/2 to matrix timer took: 32.6909 seconds
# -a^{\dagger}_{0}**3*a^{\dagger}_{2}/8 to matrix timer took: 33.1849 seconds
# -a^{\dagger}_{0}**3*a_{2}/8 to matrix timer took: 33.0258 seconds
# -a^{\dagger}_{1}**3*a^{\dagger}_{0}/8 to matrix timer took: 33.1226 seconds
# -a^{\dagger}_{1}**3*a_{0}/8 to matrix timer took: 33.1134 seconds
# -a^{\dagger}_{2}**3*a^{\dagger}_{1}/8 to matrix timer took: 33.1261 seconds
# -a^{\dagger}_{2}**3*a_{1}/8 to matrix timer took: 33.2348 seconds
# -a_{0}**3*a^{\dagger}_{2}/8 to matrix timer took: 33.1282 seconds
# -a_{0}**3*a_{2}/8 to matrix timer took: 33.2318 seconds
# -a_{1}**3*a^{\dagger}_{0}/8 to matrix timer took: 33.2363 seconds
# -a_{1}**3*a_{0}/8 to matrix timer took: 33.2351 seconds
# -a_{2}**3*a^{\dagger}_{1}/8 to matrix timer took: 32.9962 seconds
# -a_{2}**3*a_{1}/8 to matrix timer took: 32.9989 seconds
# -a^{\dagger}_{0}*a^{\dagger}_{1}/16 to matrix timer took: 33.3127 seconds
# -a^{\dagger}_{0}*a^{\dagger}_{2}/16 to matrix timer took: 33.4354 seconds
# -a^{\dagger}_{0}*a_{1}/16 to matrix timer took: 33.2886 seconds
# -a^{\dagger}_{0}*a_{2}/16 to matrix timer took: 33.3033 seconds
# -a^{\dagger}_{1}*a^{\dagger}_{0}/16 to matrix timer took: 33.2293 seconds
# -a^{\dagger}_{1}*a^{\dagger}_{2}/16 to matrix timer took: 33.2028 seconds
# -a^{\dagger}_{1}*a_{0}/16 to matrix timer took: 33.0663 seconds
# -a^{\dagger}_{1}*a_{2}/16 to matrix timer took: 33.1469 seconds
# -a^{\dagger}_{2}*a^{\dagger}_{0}/16 to matrix timer took: 33.0393 seconds
# -a^{\dagger}_{2}*a^{\dagger}_{1}/16 to matrix timer took: 32.9150 seconds
# -a^{\dagger}_{2}*a_{0}/16 to matrix timer took: 33.2579 seconds
# -a^{\dagger}_{2}*a_{1}/16 to matrix timer took: 33.0600 seconds
# -a_{0}*a^{\dagger}_{1}/16 to matrix timer took: 32.9301 seconds
# -a_{0}*a^{\dagger}_{2}/16 to matrix timer took: 33.1572 seconds
# -a_{0}*a_{1}/16 to matrix timer took: 33.2820 seconds
# -a_{0}*a_{2}/16 to matrix timer took: 33.0181 seconds
# -a_{1}*a^{\dagger}_{0}/16 to matrix timer took: 33.1462 seconds
# -a_{1}*a^{\dagger}_{2}/16 to matrix timer took: 33.3177 seconds
# -a_{1}*a_{0}/16 to matrix timer took: 33.3282 seconds
# -a_{1}*a_{2}/16 to matrix timer took: 33.3553 seconds
# -a_{2}*a^{\dagger}_{0}/16 to matrix timer took: 33.3690 seconds
# -a_{2}*a^{\dagger}_{1}/16 to matrix timer took: 33.2843 seconds
# -a_{2}*a_{0}/16 to matrix timer took: 33.4429 seconds
# -a_{2}*a_{1}/16 to matrix timer took: 33.0715 seconds
# a^{\dagger}_{0}**3*a^{\dagger}_{1}/8 to matrix timer took: 33.0424 seconds
# a^{\dagger}_{0}**3*a_{1}/8 to matrix timer took: 33.0748 seconds
# a^{\dagger}_{1}**3*a^{\dagger}_{2}/8 to matrix timer took: 33.1647 seconds
# a^{\dagger}_{1}**3*a_{2}/8 to matrix timer took: 33.1997 seconds
# a^{\dagger}_{2}**3*a^{\dagger}_{0}/8 to matrix timer took: 33.3089 seconds
# a^{\dagger}_{2}**3*a_{0}/8 to matrix timer took: 33.0132 seconds
# a_{0}**3*a^{\dagger}_{1}/8 to matrix timer took: 33.1894 seconds
# a_{0}**3*a_{1}/8 to matrix timer took: 33.2530 seconds
# a_{1}**3*a^{\dagger}_{2}/8 to matrix timer took: 33.2652 seconds
# a_{1}**3*a_{2}/8 to matrix timer took: 33.2523 seconds
# a_{2}**3*a^{\dagger}_{0}/8 to matrix timer took: 33.0642 seconds
# a_{2}**3*a_{0}/8 to matrix timer took: 33.0706 seconds
# a^{\dagger}_{0}**2*a_{0}**4/16 to matrix timer took: 33.3316 seconds
# a^{\dagger}_{0}**3*a_{0}**3/16 to matrix timer took: 33.1353 seconds
# a^{\dagger}_{0}**4*a_{0}**2/16 to matrix timer took: 33.1466 seconds
# a^{\dagger}_{0}**5*a_{0}/16 to matrix timer took: 33.2881 seconds
# a^{\dagger}_{1}**2*a_{1}**4/16 to matrix timer took: 33.4167 seconds
# a^{\dagger}_{1}**3*a_{1}**3/16 to matrix timer took: 33.3828 seconds
# a^{\dagger}_{1}**4*a_{1}**2/16 to matrix timer took: 33.4435 seconds
# a^{\dagger}_{1}**5*a_{1}/16 to matrix timer took: 33.0845 seconds
# a^{\dagger}_{2}**2*a_{2}**4/16 to matrix timer took: 33.0355 seconds
# a^{\dagger}_{2}**3*a_{2}**3/16 to matrix timer took: 33.1298 seconds
# a^{\dagger}_{2}**4*a_{2}**2/16 to matrix timer took: 32.9138 seconds
# a^{\dagger}_{2}**5*a_{2}/16 to matrix timer took: 33.2593 seconds
# a_{0}**2*a^{\dagger}_{0}**4/16 to matrix timer took: 33.3234 seconds
# a_{0}**3*a^{\dagger}_{0}**3/16 to matrix timer took: 33.3258 seconds
# a_{0}**4*a^{\dagger}_{0}**2/16 to matrix timer took: 33.2668 seconds
# a_{0}**5*a^{\dagger}_{0}/16 to matrix timer took: 33.2210 seconds
# a_{1}**2*a^{\dagger}_{1}**4/16 to matrix timer took: 33.2337 seconds
# a_{1}**3*a^{\dagger}_{1}**3/16 to matrix timer took: 33.2650 seconds
# a_{1}**4*a^{\dagger}_{1}**2/16 to matrix timer took: 32.9969 seconds
# a_{1}**5*a^{\dagger}_{1}/16 to matrix timer took: 33.0330 seconds
# a_{2}**2*a^{\dagger}_{2}**4/16 to matrix timer took: 32.9751 seconds
# a_{2}**3*a^{\dagger}_{2}**3/16 to matrix timer took: 33.0930 seconds
# a_{2}**4*a^{\dagger}_{2}**2/16 to matrix timer took: 32.9222 seconds
# a_{2}**5*a^{\dagger}_{2}/16 to matrix timer took: 33.0223 seconds
# a^{\dagger}_{0}*a_{0}**5/16 to matrix timer took: 33.1901 seconds
# a^{\dagger}_{1}*a_{1}**5/16 to matrix timer took: 32.9672 seconds
# a^{\dagger}_{2}*a_{2}**5/16 to matrix timer took: 33.0086 seconds
# a_{0}*a^{\dagger}_{0}**5/16 to matrix timer took: 33.2715 seconds
# a_{1}*a^{\dagger}_{1}**5/16 to matrix timer took: 33.0511 seconds
# a_{2}*a^{\dagger}_{2}**5/16 to matrix timer took: 32.9419 seconds
# 9*a^{\dagger}_{0}*a_{0}/8 to matrix timer took: 33.0386 seconds
# 9*a^{\dagger}_{2}*a_{2}/8 to matrix timer took: 33.0217 seconds
# 9*a_{0}*a^{\dagger}_{0}/8 to matrix timer took: 33.0293 seconds
# 9*a_{2}*a^{\dagger}_{2}/8 to matrix timer took: 33.0404 seconds
# -3*a^{\dagger}_{0}**2*\chi^{\dagger}_{0}*\chi_{0}/2 to matrix timer took: 42.8401 seconds
# -3*a^{\dagger}_{2}**2*\chi^{\dagger}_{2}*\chi_{2}/2 to matrix timer took: 41.4900 seconds
# -3*a_{0}**2*\chi^{\dagger}_{0}*\chi_{0}/2 to matrix timer took: 42.9717 seconds
# -3*a_{2}**2*\chi^{\dagger}_{2}*\chi_{2}/2 to matrix timer took: 41.9247 seconds
# -a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{2}/8 to matrix timer took: 42.9959 seconds
# -a^{\dagger}_{0}**2*a_{0}*a_{2}/8 to matrix timer took: 42.9911 seconds
# -a^{\dagger}_{1}**2*a_{1}*a^{\dagger}_{0}/8 to matrix timer took: 42.6763 seconds
# -a^{\dagger}_{1}**2*a_{1}*a_{0}/8 to matrix timer took: 42.6932 seconds
# -a^{\dagger}_{2}**2*a_{2}*a^{\dagger}_{1}/8 to matrix timer took: 42.9042 seconds
# -a^{\dagger}_{2}**2*a_{2}*a_{1}/8 to matrix timer took: 42.7830 seconds
# -a_{0}**2*a^{\dagger}_{0}*a^{\dagger}_{2}/8 to matrix timer took: 42.7391 seconds
# -a_{0}**2*a^{\dagger}_{0}*a_{2}/8 to matrix timer took: 42.5558 seconds
# -a_{1}**2*a^{\dagger}_{1}*a^{\dagger}_{0}/8 to matrix timer took: 42.8293 seconds
# -a_{1}**2*a^{\dagger}_{1}*a_{0}/8 to matrix timer took: 42.8020 seconds
# -a_{2}**2*a^{\dagger}_{2}*a^{\dagger}_{1}/8 to matrix timer took: 42.7397 seconds
# -a_{2}**2*a^{\dagger}_{2}*a_{1}/8 to matrix timer took: 42.9784 seconds
# -a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{2}/8 to matrix timer took: 43.0364 seconds
# -a^{\dagger}_{0}*a_{0}**2*a_{2}/8 to matrix timer took: 43.0869 seconds
# -a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{0}/8 to matrix timer took: 42.8322 seconds
# -a^{\dagger}_{1}*a_{1}**2*a_{0}/8 to matrix timer took: 42.7490 seconds
# -a^{\dagger}_{2}*a_{2}**2*a^{\dagger}_{1}/8 to matrix timer took: 42.7960 seconds
# -a^{\dagger}_{2}*a_{2}**2*a_{1}/8 to matrix timer took: 43.0506 seconds
# -a_{0}*a^{\dagger}_{0}**2*a^{\dagger}_{2}/8 to matrix timer took: 42.7510 seconds
# -a_{0}*a^{\dagger}_{0}**2*a_{2}/8 to matrix timer took: 43.2164 seconds
# -a_{1}*a^{\dagger}_{1}**2*a^{\dagger}_{0}/8 to matrix timer took: 43.1565 seconds
# -a_{1}*a^{\dagger}_{1}**2*a_{0}/8 to matrix timer took: 42.7426 seconds
# -a_{2}*a^{\dagger}_{2}**2*a^{\dagger}_{1}/8 to matrix timer took: 42.7426 seconds
# -a_{2}*a^{\dagger}_{2}**2*a_{1}/8 to matrix timer took: 42.7835 seconds
# a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{1}/8 to matrix timer took: 42.7455 seconds
# a^{\dagger}_{0}**2*a_{0}*a_{1}/8 to matrix timer took: 42.7613 seconds
# a^{\dagger}_{1}**2*a_{1}*a^{\dagger}_{2}/8 to matrix timer took: 42.6495 seconds
# a^{\dagger}_{1}**2*a_{1}*a_{2}/8 to matrix timer took: 43.0034 seconds
# a^{\dagger}_{2}**2*a_{2}*a^{\dagger}_{0}/8 to matrix timer took: 42.8906 seconds
# a^{\dagger}_{2}**2*a_{2}*a_{0}/8 to matrix timer took: 42.7292 seconds
# a_{0}**2*a^{\dagger}_{0}*a^{\dagger}_{1}/8 to matrix timer took: 42.6744 seconds
# a_{0}**2*a^{\dagger}_{0}*a_{1}/8 to matrix timer took: 42.7752 seconds
# a_{1}**2*a^{\dagger}_{1}*a^{\dagger}_{2}/8 to matrix timer took: 42.6239 seconds
# a_{1}**2*a^{\dagger}_{1}*a_{2}/8 to matrix timer took: 42.7069 seconds
# a_{2}**2*a^{\dagger}_{2}*a^{\dagger}_{0}/8 to matrix timer took: 42.6832 seconds
# a_{2}**2*a^{\dagger}_{2}*a_{0}/8 to matrix timer took: 42.9500 seconds
# a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{1}/8 to matrix timer took: 42.7784 seconds
# a^{\dagger}_{0}*a_{0}**2*a_{1}/8 to matrix timer took: 42.8416 seconds
# a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{2}/8 to matrix timer took: 43.2496 seconds
# a^{\dagger}_{1}*a_{1}**2*a_{2}/8 to matrix timer took: 43.0097 seconds
# a^{\dagger}_{2}*a_{2}**2*a^{\dagger}_{0}/8 to matrix timer took: 42.7279 seconds
# a^{\dagger}_{2}*a_{2}**2*a_{0}/8 to matrix timer took: 42.9122 seconds
# a_{0}*a^{\dagger}_{0}**2*a^{\dagger}_{1}/8 to matrix timer took: 42.9929 seconds
# a_{0}*a^{\dagger}_{0}**2*a_{1}/8 to matrix timer took: 42.8343 seconds
# a_{1}*a^{\dagger}_{1}**2*a^{\dagger}_{2}/8 to matrix timer took: 43.1185 seconds
# a_{1}*a^{\dagger}_{1}**2*a_{2}/8 to matrix timer took: 43.0465 seconds
# a_{2}*a^{\dagger}_{2}**2*a^{\dagger}_{0}/8 to matrix timer took: 43.0043 seconds
# a_{2}*a^{\dagger}_{2}**2*a_{0}/8 to matrix timer took: 43.0469 seconds
# a^{\dagger}_{0}**2*a_{0}**2*a^{\dagger}_{0}**2/16 to matrix timer took: 43.4564 seconds
# a^{\dagger}_{0}**2*a_{0}**3*a^{\dagger}_{0}/16 to matrix timer took: 42.6698 seconds
# a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{0}**3/16 to matrix timer took: 42.7007 seconds
# a^{\dagger}_{0}**3*a_{0}**2*a^{\dagger}_{0}/16 to matrix timer took: 42.7107 seconds
# a^{\dagger}_{0}**3*a_{0}*a^{\dagger}_{0}**2/16 to matrix timer took: 42.9769 seconds
# a^{\dagger}_{0}**4*a_{0}*a^{\dagger}_{0}/16 to matrix timer took: 43.0271 seconds
# a^{\dagger}_{1}**2*a_{1}**2*a^{\dagger}_{1}**2/16 to matrix timer took: 42.6937 seconds
# a^{\dagger}_{1}**2*a_{1}**3*a^{\dagger}_{1}/16 to matrix timer took: 42.8161 seconds
# a^{\dagger}_{1}**2*a_{1}*a^{\dagger}_{1}**3/16 to matrix timer took: 42.7264 seconds
# a^{\dagger}_{1}**3*a_{1}**2*a^{\dagger}_{1}/16 to matrix timer took: 42.9828 seconds
# a^{\dagger}_{1}**3*a_{1}*a^{\dagger}_{1}**2/16 to matrix timer took: 43.1600 seconds
# a^{\dagger}_{1}**4*a_{1}*a^{\dagger}_{1}/16 to matrix timer took: 42.9666 seconds
# a^{\dagger}_{2}**2*a_{2}**2*a^{\dagger}_{2}**2/16 to matrix timer took: 42.7122 seconds
# a^{\dagger}_{2}**2*a_{2}**3*a^{\dagger}_{2}/16 to matrix timer took: 42.6001 seconds
# a^{\dagger}_{2}**2*a_{2}*a^{\dagger}_{2}**3/16 to matrix timer took: 42.5938 seconds
# a^{\dagger}_{2}**3*a_{2}**2*a^{\dagger}_{2}/16 to matrix timer took: 42.6459 seconds
# a^{\dagger}_{2}**3*a_{2}*a^{\dagger}_{2}**2/16 to matrix timer took: 42.8630 seconds
# a^{\dagger}_{2}**4*a_{2}*a^{\dagger}_{2}/16 to matrix timer took: 42.6982 seconds
# a_{0}**2*a^{\dagger}_{0}**2*a_{0}**2/16 to matrix timer took: 43.0623 seconds
# a_{0}**2*a^{\dagger}_{0}**3*a_{0}/16 to matrix timer took: 43.1964 seconds
# a_{0}**2*a^{\dagger}_{0}*a_{0}**3/16 to matrix timer took: 43.0554 seconds
# a_{0}**3*a^{\dagger}_{0}**2*a_{0}/16 to matrix timer took: 43.1254 seconds
# a_{0}**3*a^{\dagger}_{0}*a_{0}**2/16 to matrix timer took: 42.7992 seconds
# a_{0}**4*a^{\dagger}_{0}*a_{0}/16 to matrix timer took: 42.7488 seconds
# a_{1}**2*a^{\dagger}_{1}**2*a_{1}**2/16 to matrix timer took: 42.8728 seconds
# a_{1}**2*a^{\dagger}_{1}**3*a_{1}/16 to matrix timer took: 42.7330 seconds
# a_{1}**2*a^{\dagger}_{1}*a_{1}**3/16 to matrix timer took: 42.7453 seconds
# a_{1}**3*a^{\dagger}_{1}**2*a_{1}/16 to matrix timer took: 42.9988 seconds
# a_{1}**3*a^{\dagger}_{1}*a_{1}**2/16 to matrix timer took: 42.9617 seconds
# a_{1}**4*a^{\dagger}_{1}*a_{1}/16 to matrix timer took: 42.8685 seconds
# a_{2}**2*a^{\dagger}_{2}**2*a_{2}**2/16 to matrix timer took: 42.9920 seconds
# a_{2}**2*a^{\dagger}_{2}**3*a_{2}/16 to matrix timer took: 42.9043 seconds
# a_{2}**2*a^{\dagger}_{2}*a_{2}**3/16 to matrix timer took: 42.9235 seconds
# a_{2}**3*a^{\dagger}_{2}**2*a_{2}/16 to matrix timer took: 42.7684 seconds
# a_{2}**3*a^{\dagger}_{2}*a_{2}**2/16 to matrix timer took: 42.8182 seconds
# a_{2}**4*a^{\dagger}_{2}*a_{2}/16 to matrix timer took: 42.9622 seconds
# a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{0}**3/16 to matrix timer took: 43.0377 seconds
# a^{\dagger}_{0}*a_{0}**3*a^{\dagger}_{0}**2/16 to matrix timer took: 42.7779 seconds
# a^{\dagger}_{0}*a_{0}**4*a^{\dagger}_{0}/16 to matrix timer took: 42.6759 seconds
# a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}**4/16 to matrix timer took: 42.7704 seconds
# a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{1}**3/16 to matrix timer took: 42.9191 seconds
# a^{\dagger}_{1}*a_{1}**3*a^{\dagger}_{1}**2/16 to matrix timer took: 42.8506 seconds
# a^{\dagger}_{1}*a_{1}**4*a^{\dagger}_{1}/16 to matrix timer took: 43.1445 seconds
# a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}**4/16 to matrix timer took: 43.1045 seconds
# a^{\dagger}_{2}*a_{2}**2*a^{\dagger}_{2}**3/16 to matrix timer took: 42.7752 seconds
# a^{\dagger}_{2}*a_{2}**3*a^{\dagger}_{2}**2/16 to matrix timer took: 42.7086 seconds
# a^{\dagger}_{2}*a_{2}**4*a^{\dagger}_{2}/16 to matrix timer took: 42.8971 seconds
# a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}**4/16 to matrix timer took: 42.9054 seconds
# a_{0}*a^{\dagger}_{0}**2*a_{0}**3/16 to matrix timer took: 43.2558 seconds
# a_{0}*a^{\dagger}_{0}**3*a_{0}**2/16 to matrix timer took: 43.1567 seconds
# a_{0}*a^{\dagger}_{0}**4*a_{0}/16 to matrix timer took: 42.8420 seconds
# a_{0}*a^{\dagger}_{0}*a_{0}**4/16 to matrix timer took: 42.7980 seconds
# a_{1}*a^{\dagger}_{1}**2*a_{1}**3/16 to matrix timer took: 43.2567 seconds
# a_{1}*a^{\dagger}_{1}**3*a_{1}**2/16 to matrix timer took: 42.9469 seconds
# a_{1}*a^{\dagger}_{1}**4*a_{1}/16 to matrix timer took: 42.9618 seconds
# a_{1}*a^{\dagger}_{1}*a_{1}**4/16 to matrix timer took: 43.0870 seconds
# a_{2}*a^{\dagger}_{2}**2*a_{2}**3/16 to matrix timer took: 42.9754 seconds
# a_{2}*a^{\dagger}_{2}**3*a_{2}**2/16 to matrix timer took: 43.0583 seconds
# a_{2}*a^{\dagger}_{2}**4*a_{2}/16 to matrix timer took: 43.1609 seconds
# a_{2}*a^{\dagger}_{2}*a_{2}**4/16 to matrix timer took: 43.0600 seconds
# 3*a^{\dagger}_{1}**2*\chi^{\dagger}_{1}*\chi_{1}/2 to matrix timer took: 43.0373 seconds
# 3*a_{1}**2*\chi^{\dagger}_{1}*\chi_{1}/2 to matrix timer took: 43.1660 seconds
# -3*a^{\dagger}_{0}*a_{0}*\chi^{\dagger}_{0}*\chi_{0}/2 to matrix timer took: 52.5319 seconds
# -3*a^{\dagger}_{2}*a_{2}*\chi^{\dagger}_{2}*\chi_{2}/2 to matrix timer took: 51.4349 seconds
# -3*a_{0}*a^{\dagger}_{0}*\chi^{\dagger}_{0}*\chi_{0}/2 to matrix timer took: 52.3317 seconds
# -3*a_{2}*a^{\dagger}_{2}*\chi^{\dagger}_{2}*\chi_{2}/2 to matrix timer took: 51.4102 seconds
# -a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a^{\dagger}_{2}/8 to matrix timer took: 52.6635 seconds
# -a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{2}/8 to matrix timer took: 52.4348 seconds
# -a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a^{\dagger}_{0}/8 to matrix timer took: 52.4423 seconds
# -a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{0}/8 to matrix timer took: 52.3457 seconds
# -a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}*a^{\dagger}_{1}/8 to matrix timer took: 52.5438 seconds
# -a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}*a_{1}/8 to matrix timer took: 52.6091 seconds
# -a_{0}*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{2}/8 to matrix timer took: 52.6545 seconds
# -a_{0}*a^{\dagger}_{0}*a_{0}*a_{2}/8 to matrix timer took: 52.5351 seconds
# -a_{1}*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{0}/8 to matrix timer took: 52.6035 seconds
# -a_{1}*a^{\dagger}_{1}*a_{1}*a_{0}/8 to matrix timer took: 52.5981 seconds
# -a_{2}*a^{\dagger}_{2}*a_{2}*a^{\dagger}_{1}/8 to matrix timer took: 52.7509 seconds
# -a_{2}*a^{\dagger}_{2}*a_{2}*a_{1}/8 to matrix timer took: 52.8703 seconds
# a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a^{\dagger}_{1}/8 to matrix timer took: 52.2836 seconds
# a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{1}/8 to matrix timer took: 52.9302 seconds
# a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a^{\dagger}_{2}/8 to matrix timer took: 52.4310 seconds
# a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{2}/8 to matrix timer took: 52.9639 seconds
# a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}*a^{\dagger}_{0}/8 to matrix timer took: 52.8379 seconds
# a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}*a_{0}/8 to matrix timer took: 52.7006 seconds
# a_{0}*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{1}/8 to matrix timer took: 52.8663 seconds
# a_{0}*a^{\dagger}_{0}*a_{0}*a_{1}/8 to matrix timer took: 52.7770 seconds
# a_{1}*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{2}/8 to matrix timer took: 52.7896 seconds
# a_{1}*a^{\dagger}_{1}*a_{1}*a_{2}/8 to matrix timer took: 52.8404 seconds
# a_{2}*a^{\dagger}_{2}*a_{2}*a^{\dagger}_{0}/8 to matrix timer took: 53.1307 seconds
# a_{2}*a^{\dagger}_{2}*a_{2}*a_{0}/8 to matrix timer took: 52.8954 seconds
# a^{\dagger}_{0}**2*a_{0}**2*a^{\dagger}_{0}*a_{0}/16 to matrix timer took: 53.0208 seconds
# a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{0}**2*a_{0}/16 to matrix timer took: 52.7576 seconds
# a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{0}*a_{0}**2/16 to matrix timer took: 52.2999 seconds
# a^{\dagger}_{0}**3*a_{0}*a^{\dagger}_{0}*a_{0}/16 to matrix timer took: 52.8166 seconds
# a^{\dagger}_{1}**2*a_{1}**2*a^{\dagger}_{1}*a_{1}/16 to matrix timer took: 52.5131 seconds
# a^{\dagger}_{1}**2*a_{1}*a^{\dagger}_{1}**2*a_{1}/16 to matrix timer took: 52.4486 seconds
# a^{\dagger}_{1}**2*a_{1}*a^{\dagger}_{1}*a_{1}**2/16 to matrix timer took: 52.8571 seconds
# a^{\dagger}_{1}**3*a_{1}*a^{\dagger}_{1}*a_{1}/16 to matrix timer took: 52.6676 seconds
# a^{\dagger}_{2}**2*a_{2}**2*a^{\dagger}_{2}*a_{2}/16 to matrix timer took: 52.2550 seconds
# a^{\dagger}_{2}**2*a_{2}*a^{\dagger}_{2}**2*a_{2}/16 to matrix timer took: 52.8639 seconds
# a^{\dagger}_{2}**2*a_{2}*a^{\dagger}_{2}*a_{2}**2/16 to matrix timer took: 52.4720 seconds
# a^{\dagger}_{2}**3*a_{2}*a^{\dagger}_{2}*a_{2}/16 to matrix timer took: 52.3473 seconds
# a_{0}**2*a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{0}/16 to matrix timer took: 52.3469 seconds
# a_{0}**2*a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{0}/16 to matrix timer took: 52.8107 seconds
# a_{0}**2*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}**2/16 to matrix timer took: 52.7761 seconds
# a_{0}**3*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}/16 to matrix timer took: 52.7949 seconds
# a_{1}**2*a^{\dagger}_{1}**2*a_{1}*a^{\dagger}_{1}/16 to matrix timer took: 52.5494 seconds
# a_{1}**2*a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{1}/16 to matrix timer took: 52.9501 seconds
# a_{1}**2*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}**2/16 to matrix timer took: 52.9045 seconds
# a_{1}**3*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}/16 to matrix timer took: 52.8512 seconds
# a_{2}**2*a^{\dagger}_{2}**2*a_{2}*a^{\dagger}_{2}/16 to matrix timer took: 52.9421 seconds
# a_{2}**2*a^{\dagger}_{2}*a_{2}**2*a^{\dagger}_{2}/16 to matrix timer took: 52.7067 seconds
# a_{2}**2*a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}**2/16 to matrix timer took: 52.6978 seconds
# a_{2}**3*a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}/16 to matrix timer took: 53.2040 seconds
# a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{0}**2*a_{0}/16 to matrix timer took: 53.4884 seconds
# a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{0}*a_{0}**2/16 to matrix timer took: 53.2931 seconds
# a^{\dagger}_{0}*a_{0}**3*a^{\dagger}_{0}*a_{0}/16 to matrix timer took: 53.1800 seconds
# a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}**2*a_{0}**2/16 to matrix timer took: 53.1254 seconds
# a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}**3*a_{0}/16 to matrix timer took: 53.0029 seconds
# a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{0}**3/16 to matrix timer took: 53.0231 seconds
# a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{1}**2*a_{1}/16 to matrix timer took: 52.9192 seconds
# a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{1}*a_{1}**2/16 to matrix timer took: 53.1664 seconds
# a^{\dagger}_{1}*a_{1}**3*a^{\dagger}_{1}*a_{1}/16 to matrix timer took: 53.2209 seconds
# a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}**2*a_{1}**2/16 to matrix timer took: 53.4010 seconds
# a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}**3*a_{1}/16 to matrix timer took: 52.8738 seconds
# a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{1}**3/16 to matrix timer took: 52.7537 seconds
# a^{\dagger}_{2}*a_{2}**2*a^{\dagger}_{2}**2*a_{2}/16 to matrix timer took: 52.8977 seconds
# a^{\dagger}_{2}*a_{2}**2*a^{\dagger}_{2}*a_{2}**2/16 to matrix timer took: 52.9811 seconds
# a^{\dagger}_{2}*a_{2}**3*a^{\dagger}_{2}*a_{2}/16 to matrix timer took: 52.9802 seconds
# a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}**2*a_{2}**2/16 to matrix timer took: 52.7300 seconds
# a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}**3*a_{2}/16 to matrix timer took: 52.8703 seconds
# a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}*a_{2}**3/16 to matrix timer took: 52.9208 seconds
# a_{0}*a^{\dagger}_{0}**2*a_{0}**2*a^{\dagger}_{0}/16 to matrix timer took: 53.0067 seconds
# a_{0}*a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{0}**2/16 to matrix timer took: 52.9150 seconds
# a_{0}*a^{\dagger}_{0}**3*a_{0}*a^{\dagger}_{0}/16 to matrix timer took: 53.0631 seconds
# a_{0}*a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{0}**2/16 to matrix timer took: 53.0362 seconds
# a_{0}*a^{\dagger}_{0}*a_{0}**3*a^{\dagger}_{0}/16 to matrix timer took: 53.0096 seconds
# a_{0}*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}**3/16 to matrix timer took: 52.9091 seconds
# a_{1}*a^{\dagger}_{1}**2*a_{1}**2*a^{\dagger}_{1}/16 to matrix timer took: 52.8891 seconds
# a_{1}*a^{\dagger}_{1}**2*a_{1}*a^{\dagger}_{1}**2/16 to matrix timer took: 52.9460 seconds
# a_{1}*a^{\dagger}_{1}**3*a_{1}*a^{\dagger}_{1}/16 to matrix timer took: 53.0574 seconds
# a_{1}*a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{1}**2/16 to matrix timer took: 52.9813 seconds
# a_{1}*a^{\dagger}_{1}*a_{1}**3*a^{\dagger}_{1}/16 to matrix timer took: 52.8369 seconds
# a_{1}*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}**3/16 to matrix timer took: 53.0786 seconds
# a_{2}*a^{\dagger}_{2}**2*a_{2}**2*a^{\dagger}_{2}/16 to matrix timer took: 53.0792 seconds
# a_{2}*a^{\dagger}_{2}**2*a_{2}*a^{\dagger}_{2}**2/16 to matrix timer took: 53.0368 seconds
# a_{2}*a^{\dagger}_{2}**3*a_{2}*a^{\dagger}_{2}/16 to matrix timer took: 53.0421 seconds
# a_{2}*a^{\dagger}_{2}*a_{2}**2*a^{\dagger}_{2}**2/16 to matrix timer took: 52.9088 seconds
# a_{2}*a^{\dagger}_{2}*a_{2}**3*a^{\dagger}_{2}/16 to matrix timer took: 52.9147 seconds
# a_{2}*a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}**3/16 to matrix timer took: 52.7868 seconds
# 3*a^{\dagger}_{1}*a_{1}*\chi^{\dagger}_{1}*\chi_{1}/2 to matrix timer took: 52.9676 seconds
# 3*a_{1}*a^{\dagger}_{1}*\chi^{\dagger}_{1}*\chi_{1}/2 to matrix timer took: 52.8632 seconds
# a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}/16 to matrix timer took: 62.6619 seconds
# a^{\dagger}_{1}**2*a_{1}*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}/16 to matrix timer took: 63.0781 seconds
# a^{\dagger}_{2}**2*a_{2}*a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}/16 to matrix timer took: 63.0619 seconds
# a_{0}**2*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{0}/16 to matrix timer took: 62.7874 seconds
# a_{1}**2*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{1}/16 to matrix timer took: 62.9996 seconds
# a_{2}**2*a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}*a_{2}/16 to matrix timer took: 62.8252 seconds
# a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}/16 to matrix timer took: 63.1261 seconds
# a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{0}/16 to matrix timer took: 62.7421 seconds
# a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{0}/16 to matrix timer took: 62.9623 seconds
# a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}**2/16 to matrix timer took: 63.0149 seconds
# a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}/16 to matrix timer took: 63.0284 seconds
# a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}**2*a_{1}*a^{\dagger}_{1}/16 to matrix timer took: 62.9466 seconds
# a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{1}/16 to matrix timer took: 62.9861 seconds
# a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}**2/16 to matrix timer took: 62.6223 seconds
# a^{\dagger}_{2}*a_{2}**2*a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}/16 to matrix timer took: 62.7725 seconds
# a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}**2*a_{2}*a^{\dagger}_{2}/16 to matrix timer took: 62.5294 seconds
# a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}*a_{2}**2*a^{\dagger}_{2}/16 to matrix timer took: 62.8126 seconds
# a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}**2/16 to matrix timer took: 62.5702 seconds
# a_{0}*a^{\dagger}_{0}**2*a_{0}*a^{\dagger}_{0}*a_{0}/16 to matrix timer took: 62.4976 seconds
# a_{0}*a^{\dagger}_{0}*a_{0}**2*a^{\dagger}_{0}*a_{0}/16 to matrix timer took: 62.5425 seconds
# a_{0}*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}**2*a_{0}/16 to matrix timer took: 62.4960 seconds
# a_{0}*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{0}**2/16 to matrix timer took: 62.4814 seconds
# a_{1}*a^{\dagger}_{1}**2*a_{1}*a^{\dagger}_{1}*a_{1}/16 to matrix timer took: 62.6989 seconds
# a_{1}*a^{\dagger}_{1}*a_{1}**2*a^{\dagger}_{1}*a_{1}/16 to matrix timer took: 62.4499 seconds
# a_{1}*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}**2*a_{1}/16 to matrix timer took: 63.2628 seconds
# a_{1}*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{1}**2/16 to matrix timer took: 63.0903 seconds
# a_{2}*a^{\dagger}_{2}**2*a_{2}*a^{\dagger}_{2}*a_{2}/16 to matrix timer took: 62.7046 seconds
# a_{2}*a^{\dagger}_{2}*a_{2}**2*a^{\dagger}_{2}*a_{2}/16 to matrix timer took: 62.7681 seconds
# a_{2}*a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}**2*a_{2}/16 to matrix timer took: 63.0536 seconds
# a_{2}*a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}*a_{2}**2/16 to matrix timer took: 62.6761 seconds
# a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{0}/16 to matrix timer took: 72.5992 seconds
# a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{1}/16 to matrix timer took: 72.2476 seconds
# a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}*a_{2}/16 to matrix timer took: 72.4562 seconds
# a_{0}*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}*a_{0}*a^{\dagger}_{0}/16 to matrix timer took: 73.0882 seconds
# a_{1}*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}*a_{1}*a^{\dagger}_{1}/16 to matrix timer took: 72.9009 seconds
# a_{2}*a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}*a_{2}*a^{\dagger}_{2}/16 to matrix timer took: 72.5383 seconds

# %%
ens=np.sort(np.linalg.eig(hamMat.astype(np.complex64))[0])
ens=ens.round(8)

print(np.isreal(ens).all())

ens
# Out:
# True
# array([ 0.16245385+0.j,  0.63182336+0.j,  0.88924176+0.j,  1.0958083 +0.j,
#         1.0975872 +0.j,  1.3383303 +0.j,  1.3511114 +0.j,  1.5561869 +0.j,
#         1.5650233 +0.j,  1.7612298 +0.j,  1.8372842 +0.j,  1.9574362 +0.j,
#         1.9590553 +0.j,  2.0146573 +0.j,  2.059266  +0.j,  2.1875238 +0.j,
#         2.2179966 +0.j,  2.259836  +0.j,  2.2775965 +0.j,  2.4114702 +0.j,
#         2.4189622 +0.j,  2.559221  +0.j,  2.6863763 +0.j,  2.7304463 +0.j,
#         2.7576501 +0.j,  2.76336   +0.j,  2.7719963 +0.j,  2.8995545 +0.j,
#         2.9272988 +0.j,  2.937113  +0.j,  2.9436085 +0.j,  3.1017852 +0.j,
#         3.1167312 +0.j,  3.1206114 +0.j,  3.1338205 +0.j,  3.2079763 +0.j,
#         3.2435696 +0.j,  3.3994672 +0.j,  3.4274263 +0.j,  3.594559  +0.j,
#         3.6052384 +0.j,  3.6150215 +0.j,  3.6208181 +0.j,  3.6285117 +0.j,
#         3.7612083 +0.j,  3.7884886 +0.j,  3.7948887 +0.j,  3.91954   +0.j,
#         3.9490516 +0.j,  3.9514186 +0.j,  3.9671693 +0.j,  4.1608353 +0.j,
#         4.16207   +0.j,  4.2613854 +0.j,  4.4195347 +0.j,  4.454246  +0.j,
#         4.46305   +0.j,  4.5814633 +0.j,  4.745396  +0.j,  4.8056664 +0.j,
#         5.0022225 +0.j,  5.003254  +0.j,  5.24539   +0.j,  5.7828174 +0.j,
#         5.9486494 +0.j,  5.958151  +0.j,  6.074201  +0.j,  6.0816994 +0.j,
#         6.0925007 +0.j,  6.2088056 +0.j,  6.421552  +0.j,  6.552722  +0.j,
#         6.9069695 +0.j,  6.909002  +0.j,  6.9678564 +0.j,  6.9781566 +0.j,
#         7.0380225 +0.j,  7.0405035 +0.j,  7.097849  +0.j,  7.1106963 +0.j,
#         7.47251   +0.j,  7.603853  +0.j,  7.6216936 +0.j,  7.623948  +0.j,
#         7.7437124 +0.j,  7.7602944 +0.j,  7.7647285 +0.j,  7.8141637 +0.j,
#         7.8840847 +0.j,  7.9346223 +0.j,  7.935104  +0.j,  7.942423  +0.j,
#         8.063368  +0.j,  8.0637665 +0.j,  8.08731   +0.j,  8.224379  +0.j,
#         8.571595  +0.j,  8.576048  +0.j,  8.636488  +0.j,  8.641613  +0.j,
#         8.709098  +0.j,  8.713064  +0.j,  8.719451  +0.j,  8.726283  +0.j,
#         8.773205  +0.j,  8.77941   +0.j,  8.829341  +0.j,  8.83316   +0.j,
#         8.843301  +0.j,  8.95199   +0.j,  9.138483  +0.j,  9.190704  +0.j,
#         9.275816  +0.j,  9.296645  +0.j,  9.476087  +0.j,  9.597096  +0.j,
#         9.59749   +0.j,  9.610326  +0.j,  9.675742  +0.j,  9.678327  +0.j,
#         9.731738  +0.j,  9.73241   +0.j,  9.738471  +0.j,  9.746057  +0.j,
#         9.781611  +0.j,  9.784372  +0.j,  9.845765  +0.j,  9.850697  +0.j,
#        10.241546  +0.j, 10.347586  +0.j, 10.58313   +0.j, 10.619908  +0.j,
#        10.624836  +0.j, 10.686297  +0.j, 10.701977  +0.j, 10.70367   +0.j,
#        10.736846  +0.j, 10.737724  +0.j, 10.742807  +0.j, 10.8067465 +0.j,
#        10.807848  +0.j, 10.857269  +0.j, 11.08896   +0.j, 11.200711  +0.j,
#        11.572586  +0.j, 11.577528  +0.j, 11.636671  +0.j, 11.64394   +0.j,
#        11.684489  +0.j, 11.689294  +0.j, 11.749628  +0.j, 11.754653  +0.j,
#        12.13908   +0.j, 12.250899  +0.j, 12.479597  +0.j, 12.588771  +0.j,
#        12.599198  +0.j, 12.599963  +0.j, 12.707872  +0.j, 12.708903  +0.j,
#        13.048905  +0.j, 13.060762  +0.j, 13.064888  +0.j, 13.35047   +0.j,
#        13.363722  +0.j, 13.367814  +0.j, 13.893584  +0.j, 13.896536  +0.j,
#        13.897394  +0.j, 13.906145  +0.j, 13.907394  +0.j, 13.948158  +0.j,
#        14.191489  +0.j, 14.191948  +0.j, 14.206857  +0.j, 14.2074995 +0.j,
#        14.243273  +0.j, 14.2696495 +0.j, 14.281068  +0.j, 14.287548  +0.j,
#        14.292472  +0.j, 14.336722  +0.j, 14.337686  +0.j, 14.423154  +0.j,
#        14.692403  +0.j, 14.74514   +0.j, 14.746689  +0.j, 14.7973585 +0.j,
#        14.820084  +0.j, 15.061798  +0.j, 15.070191  +0.j, 15.074466  +0.j,
#        15.077685  +0.j, 15.082969  +0.j, 15.083699  +0.j, 15.113734  +0.j,
#        15.114587  +0.j, 15.132106  +0.j, 15.135063  +0.j, 15.165726  +0.j,
#        15.191109  +0.j, 15.192795  +0.j, 15.259373  +0.j, 15.263165  +0.j,
#        15.318153  +0.j, 15.320645  +0.j, 15.633289  +0.j, 15.760995  +0.j,
#        15.885833  +0.j, 15.886172  +0.j, 15.900346  +0.j, 15.900785  +0.j,
#        15.908405  +0.j, 15.909033  +0.j, 15.95197   +0.j, 15.960674  +0.j,
#        15.97234   +0.j, 16.022182  +0.j, 16.022224  +0.j, 16.027882  +0.j,
#        16.108875  +0.j, 16.124897  +0.j, 16.12694   +0.j, 16.152187  +0.j,
#        16.249489  +0.j, 16.252247  +0.j, 16.36824   +0.j, 16.501627  +0.j,
#        16.80711   +0.j, 16.811676  +0.j, 16.865007  +0.j, 16.869486  +0.j,
#        16.94083   +0.j, 16.945026  +0.j, 16.974451  +0.j, 16.974987  +0.j,
#        16.9988    +0.j, 17.00276   +0.j, 17.060225  +0.j, 17.080038  +0.j,
#        17.080627  +0.j, 17.166231  +0.j, 17.308928  +0.j, 17.442547  +0.j,
#        17.459972  +0.j, 17.56312   +0.j, 17.698765  +0.j, 17.797356  +0.j,
#        17.798056  +0.j, 17.829334  +0.j, 17.899584  +0.j, 17.902576  +0.j,
#        17.928112  +0.j, 17.929321  +0.j, 17.957247  +0.j, 17.958876  +0.j,
#        17.995558  +0.j, 18.002836  +0.j, 18.005716  +0.j, 18.012472  +0.j,
#        18.018366  +0.j, 18.058668  +0.j, 18.059887  +0.j, 18.064936  +0.j,
#        18.077126  +0.j, 18.086266  +0.j, 18.400629  +0.j, 18.50386   +0.j,
#        18.792454  +0.j, 18.847094  +0.j, 18.849566  +0.j, 18.880663  +0.j,
#        18.880697  +0.j, 18.890965  +0.j, 18.892622  +0.j, 18.894758  +0.j,
#        18.900032  +0.j, 18.91189   +0.j, 18.916975  +0.j, 18.964283  +0.j,
#        18.966637  +0.j, 18.992188  +0.j, 18.992462  +0.j, 18.993513  +0.j,
#        18.994783  +0.j, 19.078194  +0.j, 19.365236  +0.j, 19.474066  +0.j,
#        19.507868  +0.j, 19.621925  +0.j, 19.803322  +0.j, 19.808558  +0.j,
#        19.861183  +0.j, 19.866282  +0.j, 19.912401  +0.j, 19.91728   +0.j,
#        19.970081  +0.j, 19.975128  +0.j, 20.304897  +0.j, 20.41378   +0.j,
#        20.697645  +0.j, 20.722628  +0.j, 20.79458   +0.j, 20.796162  +0.j,
#        20.80395   +0.j, 20.901922  +0.j, 20.903725  +0.j, 21.025028  +0.j,
#        21.27168   +0.j, 21.279716  +0.j, 21.282581  +0.j, 21.289686  +0.j,
#        21.558432  +0.j, 21.570074  +0.j, 21.580956  +0.j, 21.582602  +0.j,
#        21.592665  +0.j, 21.675774  +0.j, 21.775345  +0.j, 21.877874  +0.j,
#        21.932112  +0.j, 21.968742  +0.j, 22.046259  +0.j, 22.048468  +0.j,
#        22.075815  +0.j, 22.105719  +0.j, 22.113182  +0.j, 22.113953  +0.j,
#        22.114626  +0.j, 22.116205  +0.j, 22.1201    +0.j, 22.120668  +0.j,
#        22.124949  +0.j, 22.401577  +0.j, 22.404123  +0.j, 22.412935  +0.j,
#        22.415535  +0.j, 22.479534  +0.j, 22.486685  +0.j, 22.49102   +0.j,
#        22.495378  +0.j, 22.515154  +0.j, 22.60947   +0.j, 22.616852  +0.j,
#        22.729033  +0.j, 22.7369    +0.j, 22.8793    +0.j, 22.909685  +0.j,
#        22.910664  +0.j, 22.913     +0.j, 22.951406  +0.j, 22.951752  +0.j,
#        22.960062  +0.j, 22.960485  +0.j, 22.98242   +0.j, 23.277931  +0.j,
#        23.282825  +0.j, 23.286978  +0.j, 23.288862  +0.j, 23.289608  +0.j,
#        23.291998  +0.j, 23.29707   +0.j, 23.299606  +0.j, 23.314926  +0.j,
#        23.317804  +0.j, 23.319473  +0.j, 23.32247   +0.j, 23.45536   +0.j,
#        23.49482   +0.j, 23.671253  +0.j, 23.679874  +0.j, 23.779833  +0.j,
#        23.787767  +0.j, 23.819431  +0.j, 24.107832  +0.j, 24.11013   +0.j,
#        24.111038  +0.j, 24.113419  +0.j, 24.11692   +0.j, 24.11923   +0.j,
#        24.119457  +0.j, 24.12185   +0.j, 24.611193  +0.j, 24.619972  +0.j,
#        25.669397  +0.j, 25.733746  +0.j, 26.216385  +0.j, 26.226223  +0.j,
#        26.230669  +0.j, 26.231777  +0.j, 26.281471  +0.j, 26.289719  +0.j,
#        26.294935  +0.j, 26.29611   +0.j, 26.622826  +0.j, 26.685461  +0.j,
#        26.721104  +0.j, 26.785336  +0.j, 27.06091   +0.j, 27.062185  +0.j,
#        27.062723  +0.j, 27.06526   +0.j, 27.123577  +0.j, 27.124704  +0.j,
#        27.125624  +0.j, 27.127539  +0.j, 27.174688  +0.j, 27.285927  +0.j,
#        27.563738  +0.j, 27.626282  +0.j, 27.703844  +0.j, 27.814995  +0.j,
#        28.203293  +0.j, 28.314285  +0.j, 29.444935  +0.j, 29.49203   +0.j,
#        29.492056  +0.j, 29.546768  +0.j, 29.71434   +0.j, 29.720964  +0.j,
#        29.743073  +0.j, 29.790037  +0.j, 29.790363  +0.j, 30.076317  +0.j,
#        30.239912  +0.j, 30.254608  +0.j, 30.268757  +0.j, 30.315453  +0.j,
#        30.316328  +0.j, 30.326782  +0.j, 30.328665  +0.j, 30.339296  +0.j,
#        30.56831   +0.j, 30.570597  +0.j, 30.581284  +0.j, 30.617216  +0.j,
#        30.619858  +0.j, 30.631916  +0.j, 30.637466  +0.j, 30.684103  +0.j,
#        30.685154  +0.j, 30.743279  +0.j, 30.750875  +0.j, 31.093544  +0.j,
#        31.113756  +0.j, 31.148516  +0.j, 31.155638  +0.j, 31.156511  +0.j,
#        31.167404  +0.j, 31.440165  +0.j, 31.448162  +0.j, 31.487116  +0.j,
#        31.487465  +0.j, 31.495153  +0.j, 31.49544   +0.j, 31.514902  +0.j,
#        31.516695  +0.j, 31.527563  +0.j, 31.597816  +0.j, 31.608446  +0.j,
#        31.67807   +0.j, 32.177147  +0.j, 32.31267   +0.j, 32.313286  +0.j,
#        32.3215    +0.j, 32.321976  +0.j, 32.324005  +0.j, 32.33282   +0.j,
#        34.385246  +0.j, 34.432037  +0.j, 34.43253   +0.j, 34.447876  +0.j,
#        34.494625  +0.j, 34.49522   +0.j, 35.26791   +0.j, 35.27043   +0.j,
#        35.280552  +0.j, 35.32941   +0.j, 35.330948  +0.j, 35.341442  +0.j,
#        35.400112  +0.j, 35.50846   +0.j, 35.867985  +0.j, 35.976185  +0.j,
#        36.367508  +0.j, 36.475586  +0.j, 37.774445  +0.j, 37.94211   +0.j,
#        37.94984   +0.j, 38.242657  +0.j, 38.406784  +0.j, 38.421494  +0.j,
#        38.741753  +0.j, 38.789654  +0.j, 38.79962   +0.j, 38.91037   +0.j,
#        38.91739   +0.j, 39.252018  +0.j, 39.27215   +0.j, 39.36297   +0.j,
#        39.756744  +0.j, 39.766365  +0.j, 39.830402  +0.j, 40.329613  +0.j,
#        44.061718  +0.j, 44.167057  +0.j, 46.438744  +0.j, 46.610657  +0.j,
#        46.61066   +0.j, 47.450134  +0.j, 47.45015   +0.j, 48.012363  +0.j],
#       dtype=complex64)
